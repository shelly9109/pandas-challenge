# %%
import pandas as pd

# %%
school_file = "PyCitySchools/PyCitySchools/Resources/schools_complete.csv"
school_df = pd.read_csv(school_file)
student_file = "PyCitySchools/PyCitySchools/Resources/students_complete.csv"
student_df = pd.read_csv(student_file)

# please note that I started on this before realizing I could merge the two data sets in the beginning
# with (school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
# I tried to clean up and simplify the code afterward, but kept messing it up. So I'm leaving it as is.

# %%
# DISTRICT SUMMARY

total_schools = school_df["school_name"].count()
total_students = student_df["school_name"].count()
total_budget = school_df["budget"].sum()
avg_math_score = student_df["math_score"].mean()
avg_reading_score = student_df["reading_score"].mean()

passing_math = student_df.loc[(student_df["math_score"] >= 70)]
count_passing_math = passing_math["math_score"].count()
percent_passing_math = (count_passing_math / total_students)*100

passing_reading = student_df.loc[(student_df["reading_score"] >= 70)]
count_passing_reading = passing_reading["reading_score"].count()
percent_passing_reading = (count_passing_reading / total_students)*100

overall_passing_rate = (percent_passing_math + percent_passing_reading)/2

district_summary = {"Total Schools" : total_schools,
                    "Total Students" : total_students,
                    "Total Budget" : total_budget,
                    "Average Math Score" : avg_math_score,
                    "Average Reading Score" : avg_reading_score,
                    "% Passing Math" : percent_passing_math,
                    "% Passing Reading" : percent_passing_reading,
                    "% Overall Passing" : overall_passing_rate}
district_summary_df = pd.DataFrame([district_summary])
district_summary_df = district_summary_df[["Total Schools", "Total Students", 
                                           "Total Budget", "Average Math Score", 
                                           "Average Reading Score", "% Passing Math", 
                                           "% Passing Reading", "% Overall Passing"]]

district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          80.393158

# %%
#SCHOOL SUMMARY

school_df['Per Student Budget'] = school_df['budget']/school_df['size']
avg_math_read_tbl = renamed_student_df.groupby(['school_name'])['reading_score', 'math_score'].mean().reset_index()
school_df = school_df.merge(avg_math_read_tbl, on='school_name', how="outer")

summary_passing_read = renamed_student_df[renamed_student_df['reading_score']>=70]
summary_passing_math = renamed_student_df[renamed_student_df['math_score']>=70]
pass_read_count_sum = summary_passing_read.groupby(["school_name"])['reading_score'].count().reset_index()
pass_read_count_sum.rename({'reading_score' : 'Reading Count'}, axis=1, inplace=True)
pass_math_count_sum = summary_passing_math.groupby(["school_name"])['math_score'].count().reset_index()
pass_math_count_sum.rename({'math_score' : 'Math Count'}, axis=1, inplace=True)
pass_count = pass_math_count_sum.merge(pass_read_count_sum, on="school_name", how='inner')
school_df = school_df.merge(pass_count, on="school_name", how='outer')

school_df['% Passing Math'] = (school_df['Math Count']/school_df['size'])*100
school_df['% Passing Reading'] = (school_df['Reading Count']/school_df['size'])*100

school_df['% Overall Passing'] = (school_df['% Passing Math'] + school_df['% Passing Reading'])/2

school_df.rename({'reading_score':'Avg. Reading Score', 'math_score':'Avg. Math Score'}, axis=1, inplace=True)

school_df
# Out:
#     School ID            school_name      type  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
# TOP PERFORMING SCHOOLS (BY PASSING RATE)
top_performing_by_pr_df = school_df.sort_values(by=['% Overall Passing'], ascending=False).head(5)
top_performing_by_pr_df.head(5)
# Out:
#     School ID          school_name     type  size   budget  \
# 6           6  Cabrera High School  Charter  1858  1081356
# 14         14   Thomas High School  Charter  1635  1043130
# 9           9     Pena High School  Charter   962   585858
# 4           4  Griffin High School  Charter  1468   917500
# 5           5   Wilson High School  Charter  2283  1319574
#
#     Per Student Budget  Avg. Reading Score  Avg. Math Score  % Passing Math  \
# 6                582.0           83.975780        83.061895       94.133477
# 14               638.0           83.848930        83.418349       93.272171
# 9                609.0           84.044699        83.839917       94.594595
# 4                625.0           83.816757        83.351499       93.392371
# 5                578.0           83.989488        83.274201       93.867718
#
#     % Passing Reading  % Overall Passing
# 6           97.039828          95.586652
# 14          97.308869          95.290520
# ...

# %%
# BOTTOM PERFORMING SCHOOLS (BY PASSING RATE)
worst_performing_by_pr_df = school_df.sort_values(by=['% Overall Passing']).head(5)
worst_performing_by_pr_df
# Out:
#     School ID            school_name      type  size   budget  \
# 11         11  Rodriguez High School  District  3999  2547363
# 1           1   Figueroa High School  District  2949  1884411
# 0           0      Huang High School  District  2917  1910635
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
#
#     Per Student Budget  Avg. Reading Score  Avg. Math Score  % Passing Math  \
# 11               637.0           80.744686        76.842711       66.366592
# 1                639.0           81.158020        76.711767       65.988471
# 0                655.0           81.182722        76.629414       65.683922
# 12               650.0           80.966394        77.072464       66.057551
# 13               644.0           80.746258        77.102592       68.309602
#
#     % Passing Reading  % Overall Passing
# 11          80.220055          73.293323
# 1           80.739234          73.363852
# ...

# %%
# MATH SCORES BY GRADE
math_scores_by_grade_df = pd.pivot_table(student_df, values=['math_score'], index=['school_name'], columns=['grade'])
math_scores_by_grade_df = math_scores_by_grade_df.reindex(labels=['9th', '10th', '11th','12th'], axis=1, level=1)

math_scores_by_grade_df
# Out:
#                       math_score
# grade                        9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# ...

# %%
# READING SCORES BY GRADE
read_scores_by_grade_df = pd.pivot_table(student_df, values=['reading_score'], index=['school_name'], columns=['grade'])
read_scores_by_grade_df = read_scores_by_grade_df.reindex(labels=['9th', '10th', '11th', '12th'], axis=1, level=1)

read_scores_by_grade_df
# Out:
#                       reading_score
# grade                           9th       10th       11th       12th
# school_name
# Bailey High School        81.303155  80.907183  80.945643  80.912451
# Cabrera High School       83.676136  84.253219  83.788382  84.287958
# Figueroa High School      81.198598  81.408912  80.640339  81.384863
# Ford High School          80.632653  81.262712  80.403642  80.662338
# Griffin High School       83.369193  83.706897  84.288089  84.013699
# Hernandez High School     80.866860  80.660147  81.396140  80.857143
# Holden High School        83.677165  83.324561  83.815534  84.698795
# Huang High School         81.290284  81.512386  81.417476  80.305983
# Johnson High School       81.260714  80.773431  80.616027  81.227564
# Pena High School          83.807273  83.612000  84.335938  84.591160
# Rodriguez High School     80.993127  80.629808  80.864811  80.376426
# Shelton High School       84.122642  83.441964  84.373786  82.781671
# ...

# %%
# SCORES BY SCHOOL SPENDING
scores_by_school_spending = school_df.copy()
bins = [0, 580, 610, 650, 680]
spending_labels = ['$0-$580', '$580-$620', '$620-$650', '$650-$680']
bins_school_spending = pd.cut(scores_by_school_spending['Per Student Budget'], bins, labels=spending_labels)
bins_school_spending = pd.DataFrame(bins_school_spending)
school_df['Spending Level'] = bins_school_spending
scores_by_school_spending = copy_school_sum.groupby(['Spending Level'])['Avg. Reading Score',
                                                         'Avg. Math Score',
                                                         '% Passing Reading',
                                                         '% Passing Math',
                                                         '% Overall Passing'
                                                         ].mean()scores_by_school_spending
# Out:
#   File "<ipython-input-194-98792b6e9955>", line 13
#     ].mean()scores_by_school_spending
#                                     ^
# SyntaxError: invalid syntax

# %%
# SCORES BY SCHOOL SIZE
scores_by_school_size = copy_school_sum.copy()
bins = [0, 1000, 2000, 5000]
size_labels = ['Small', 'Medium', 'Large']
bins_school_size = pd.cut(scores_by_school_size['size'], bins, labels = size_labels)
bins_school_size = pd.DataFrame(bins_school_size)
copy_school_sum['School Population'] = bins_school_size
scores_by_school_size = copy_school_sum.groupby(['School Population','school_name'])['Avg. Reading Score',
                                                         'Avg. Math Score',
                                                         '% Passing Reading',
                                                         '% Passing Math',
                                                         '% Overall Passing'
                                                         ].mean()
scores_by_school_size
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-193-bb64e9edaa26> in <module>
#       6 bins_school_size = pd.DataFrame(bins_school_size)
#       7 copy_school_sum['School Population'] = bins_school_size
# ----> 8 scores_by_school_size = copy_school_sum.groupby(['School Population','school_name'])['Avg. Reading Score',
#       9                                                          'Avg. Math Score',
#      10                                                          '% Passing Reading',
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     263                 bad_keys = list(set(key).difference(self.obj.columns))
#     264                 raise KeyError("Columns not found: {missing}"
# --> 265                                .format(missing=str(bad_keys)[1:-1]))
# ...

# %%
# SCORES BY SCHOOL TYPE
scores_by_school_type = school_df.copy()
scores_by_school_type = pd.DataFrame(scores_by_school_type)
scores_by_school_type = school_df.groupby(['type'])['Avg. Reading Score',
                                                         'Avg. Math Score',
                                                         '% Passing Reading',
                                                         '% Passing Math',
                                                         '% Overall Passing'
                                                         ].mean()
scores_by_school_type.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-196-979b7372dc17> in <module>
#       2 scores_by_school_type = school_df.copy()
#       3 scores_by_school_type = pd.DataFrame(scores_by_school_type)
# ----> 4 scores_by_school_type = school_df.groupby(['type'])['Avg. Reading Score',
#       5                                                          'Avg. Math Score',
#       6                                                          '% Passing Reading',
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     263                 bad_keys = list(set(key).difference(self.obj.columns))
#     264                 raise KeyError("Columns not found: {missing}"
# --> 265                                .format(missing=str(bad_keys)[1:-1]))
#     266             return self._gotitem(list(key), ndim=2)
#     267
#
# ...
